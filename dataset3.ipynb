# %% [markdown]
# check the shape after splitinng

# %%
print(f"x_train: {x_train.shape}")
print(f"x_test: {x_test.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"x_train: {x_train.shape}")
#       2 print(f"x_test: {x_test.shape}")
#       3 print(f"y_train: {y_train.shape}")
#
# NameError: name 'x_train' is not defined

# %%
students.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 students.head()
#
# NameError: name 'students' is not defined

# %%
from sklearn.preprocessing import standardscaler
scaler=standardscaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

x_train_scaled
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.preprocessing import standardscaler
#       2 scaler=standardscaler()
#       4 x_train_scaled = scaler.fit_transform(x_train)
#
# ImportError: cannot import name 'standardscaler' from 'sklearn.preprocessing' (c:\Users\Piyush Deo\Desktop\ml_env\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %% [markdown]
# create and train logistic regression

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

# %%
print("model training starting...")
model.fit(x_train_scaled,y_train)
# Out:
# model training starting...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 print("model training starting...")
# ----> 2 model.fit(x_train_scaled,y_train)
#
# NameError: name 'x_train_scaled' is not defined

# %%
coefficients=np.round(model.coef_[0],3)
intercepts=np.round(model.intercept_,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 coefficients=np.round(model.coef_[0],3)
#       2 intercepts=np.round(model.intercept_,3)
#
# NameError: name 'np' is not defined

# %%
print(f"coefficient of study hours: {coefficients[0]}")
print(f"coefficient of attendances: {coefficeints[1]}")
print(f"intercept: {intercepts[0]}")


print(f"equation: study:hours * {coefficeints[0]} + attendance * {coefficients[1]} + {intercepts[0]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(f"coefficient of study hours: {coefficients[0]}")
#       2 print(f"coefficient of attendances: {coefficeints[1]}")
#       3 print(f"intercept: {intercepts[0]}")
#
# NameError: name 'coefficients' is not defined

# %% [markdown]
# make prediction on test dataset

# %%
y_pred=model.predict(x_test_scaled)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 y_pred=model.predict(x_test_scaled)
#       2 y_pred
#
# NameError: name 'x_test_scaled' is not defined

# %%
check=pd.DataFrame({
    "Actual":y_test,
    "predicted":y_pred
})
check
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 check=pd.DataFrame({
#       2     "Actual":y_test,
#       3     "predicted":y_pred
#       4 })
#       5 check
#
# NameError: name 'pd' is not defined

# %% [markdown]
# evaluate the model

# %%
from sklearn.base import accuracy_score,confusion_matrix

accuracy=accuracy_score(y_test,y_pred)

print(f"Accuracy of the model is {accuracy*100}%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from sklearn.base import accuracy_score,confusion_matrix
#       3 accuracy=accuracy_score(y_test,y_pred)
#       5 print(f"Accuracy of the model is {accuracy*100}%")
#
# ImportError: cannot import name 'accuracy_score' from 'sklearn.base' (c:\Users\Piyush Deo\Desktop\ml_env\Lib\site-packages\sklearn\base.py)

# %% [markdown]
# confusion matrix

# %%
conf_matrix=confusion_matrix(y_test,y_pred)
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 conf_matrix=confusion_matrix(y_test,y_pred)
#       2 print(conf_matrix)
#
# NameError: name 'confusion_matrix' is not defined

# %% [markdown]
# visualize the confusion matrix

# %%
sns.heatmap(data=conf_matrix,annot=True)
plt.xlabel("predbicted")
plt.ylabel("Actual")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.heatmap(data=conf_matrix,annot=True)
#       2 plt.xlabel("predbicted")
#       3 plt.ylabel("Actual")
#
# NameError: name 'sns' is not defined
