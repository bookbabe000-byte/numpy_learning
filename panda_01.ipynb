# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### to store one dimension data using pandas series datastructure

# %%
list1=["a","b","c","d","e"]
series1=pd.Series(list1,index=['A','B','C','D','E'])

# %%
series1
# Out:
# A    a
# B    b
# C    c
# D    d
# E    e
# dtype: object

# %%
array=np.random.randint(20,25,
size=(9))

# %%
array
# Out:
# array([24, 23, 20, 21, 24, 24, 24, 23, 20], dtype=int32)

# %%
series2=pd.Series(array)

# %%
series2
# Out:
# 0    24
# 1    23
# 2    20
# 3    21
# 4    24
# 5    24
# 6    24
# 7    23
# 8    20
# dtype: int32

# %%
series3=pd.Series(np.random.randint(30,35,size=(10)))

# %%
series3
# Out:
# 0    32
# 1    33
# 2    34
# 3    34
# 4    34
# 5    32
# 6    32
# 7    33
# 8    31
# 9    32
# dtype: int32

# %%
print(series1,series2,series3)
# Out:
# A    a
# B    b
# C    c
# D    d
# E    e
# dtype: object 0    24
# 1    23
# 2    20
# 3    21
# 4    24
# 5    24
# 6    24
# 7    23
# 8    20
# dtype: int32 0    32
# 1    33
# 2    34
# 3    34
# 4    34
# 5    32
# 6    32
# 7    33
# 8    31
# 9    32
# dtype: int32

# %%
print(series2+series3)
# Out:
# 0    56.0
# 1    56.0
# 2    54.0
# 3    55.0
# 4    58.0
# 5    56.0
# 6    56.0
# 7    56.0
# 8    51.0
# 9     NaN
# dtype: float64

# %%
print(series2-series3)
# Out:
# 0    -8.0
# 1   -10.0
# 2   -14.0
# 3   -13.0
# 4   -10.0
# 5    -8.0
# 6    -8.0
# 7   -10.0
# 8   -11.0
# 9     NaN
# dtype: float64

# %%
print(series2%series3)
# Out:
# 0    24.0
# 1    23.0
# 2    20.0
# 3    21.0
# 4    24.0
# 5    24.0
# 6    24.0
# 7    23.0
# 8    20.0
# 9     NaN
# dtype: float64

# %%
print(series2/series3)
# Out:
# 0    0.750000
# 1    0.696970
# 2    0.588235
# 3    0.617647
# 4    0.705882
# 5    0.750000
# 6    0.750000
# 7    0.696970
# 8    0.645161
# 9         NaN
# dtype: float64

# %% [markdown]
# dataframe

# %%
students=["student1",
          "student2",
          "student3",
          "student4",
          "student5"]
rollno=["001",
        "002",
        "003",
        "004",
        "005"]
scores=[45,56,67,89,45]

# %%
record={
    "student":students,
    "rollno":rollno,
    "scores":scores
}

# %%
record
# Out:
# {'student': ['student1', 'student2', 'student3', 'student4', 'student5'],
#  'rollno': ['001', '002', '003', '004', '005'],
#  'scores': [45, 56, 67, 89, 45]}

# %%
record_df=pd.DataFrame(record)

# %%
record_df
# Out:
#     student rollno  scores
# 0  student1    001      45
# 1  student2    002      56
# 2  student3    003      67
# 3  student4    004      89
# 4  student5    005      45

# %%
record_df.set_index(["rollno","scores"])
# Out:
#                 student
# rollno scores
# 001    45      student1
# 002    56      student2
# 003    67      student3
# 004    89      student4
# 005    45      student5

# %%
dict1={
    "A":[1,23,45,67,56],
    "B":[13,45,67,89,70],
    "C":[23,45,77,12,90],
    "D":[34,55,43,56,67],
    "E":[24,56,78,90,45]

}
dict1
# Out:
# {'A': [1, 23, 45, 67, 56],
#  'B': [13, 45, 67, 89, 70],
#  'C': [23, 45, 77, 12, 90],
#  'D': [34, 55, 43, 56, 67],
#  'E': [24, 56, 78, 90, 45]}

# %%
dict_df=pd.DataFrame(dict1)

# %%
dict_df
# Out:
#     A   B   C   D   E
# 0   1  13  23  34  24
# 1  23  45  45  55  56
# 2  45  67  77  43  78
# 3  67  89  12  56  90
# 4  56  70  90  67  45

# %%
df_1=pd.DataFrame(dict1)

# %%
df_1
# Out:
#     A   B   C   D   E
# 0   1  13  23  34  24
# 1  23  45  45  55  56
# 2  45  67  77  43  78
# 3  67  89  12  56  90
# 4  56  70  90  67  45

# %%
df_1.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df_1["A"]
# Out:
# 0     1
# 1    23
# 2    45
# 3    67
# 4    56
# Name: A, dtype: int64

# %%
df_1["A"]
# Out:
# 0     1
# 1    23
# 2    45
# 3    67
# 4    56
# Name: A, dtype: int64

# %%
df_1["E"]=df_1["A"]+df_1["B"] +df_1["C"] +df_1["D"]
df_1
# Out:
#     A   B   C   D    E
# 0   1  13  23  34   71
# 1  23  45  45  55  168
# 2  45  67  77  43  232
# 3  67  89  12  56  224
# 4  56  70  90  67  283

# %%
df_1["F"]=df_1["E"]/4
df_1
# Out:
#     A   B   C   D    E      F
# 0   1  13  23  34   71  17.75
# 1  23  45  45  55  168  42.00
# 2  45  67  77  43  232  58.00
# 3  67  89  12  56  224  56.00
# 4  56  70  90  67  283  70.75

# %% [markdown]
# ### INFO METHOD

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
#  3   D       5 non-null      int64
#  4   E       5 non-null      int64
#  5   F       5 non-null      float64
# dtypes: float64(1), int64(5)
# memory usage: 372.0 bytes

# %% [markdown]
# handaling null value

# %%
dict2={
    "students":["student1", "student2","student3","student4","student5"],
    "rollno":["001", np.nan,"004","005",np.nan],
    "gender":["male","female","male","female","male"],
    "markss_obtained":[45,67,89,34,56]

}

# %%
dict2
# Out:
# {'students': ['student1', 'student2', 'student3', 'student4', 'student5'],
#  'rollno': ['001', nan, '004', '005', nan],
#  'gender': ['male', 'female', 'male', 'female', 'male'],
#  'markss_obtained': [45, 67, 89, 34, 56]}

# %%
student_df=pd.DataFrame(dict2)

# %%
student_df
# Out:
#    students rollno  gender  markss_obtained
# 0  student1    001    male               45
# 1  student2    NaN  female               67
# 2  student3    004    male               89
# 3  student4    005  female               34
# 4  student5    NaN    male               56

# %% [markdown]
# to check null alue

# %%
student_df.isnull()
# Out:
#    students  rollno  gender  markss_obtained
# 0     False   False   False            False
# 1     False    True   False            False
# 2     False   False   False            False
# 3     False   False   False            False
# 4     False    True   False            False

# %%
student_df.isna()
# Out:
#    students  rollno  gender  markss_obtained
# 0     False   False   False            False
# 1     False    True   False            False
# 2     False   False   False            False
# 3     False   False   False            False
# 4     False    True   False            False

# %%
student_df.isnull().sum()
# Out:
# students           0
# rollno             2
# gender             0
# markss_obtained    0
# dtype: int64

# %% [markdown]
# to check duplicate value in the record

# %%
student_df.nunique()
# Out:
# students           5
# rollno             3
# gender             2
# markss_obtained    5
# dtype: int64

# %%
student_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
student_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# rmoving duplicate values

# %%
student_df.drop_duplicates()
# Out:
#    students rollno  gender  markss_obtained
# 0  student1    001    male               45
# 1  student2    NaN  female               67
# 2  student3    004    male               89
# 3  student4    005  female               34
# 4  student5    NaN    male               56

# %% [markdown]
# to drop null values

# %%
student_df.dropna()
# Out:
#    students rollno  gender  markss_obtained
# 0  student1    001    male               45
# 2  student3    004    male               89
# 3  student4    005  female               34

# %% [markdown]
# ### mean and mode impuation

# %%
student_df
# Out:
#    students rollno  gender  markss_obtained
# 0  student1    001    male               45
# 1  student2    NaN  female               67
# 2  student3    004    male               89
# 3  student4    005  female               34
# 4  student5    NaN    male               56

# %%
student_df.dropna()
# Out:
#    students rollno  gender  markss_obtained
# 0  student1    001    male               45
# 2  student3    004    male               89
# 3  student4    005  female               34

# %%
rollno_mode=student_df['rollno'].mode()

# %%
rollno
# Out:
# ['001', '002', '003', '004', '005']

# %%
gender_mode=student_df['gender'].mode()[0]

# %%
gender_mode
# Out:
# 'male'

# %%
marks_mean=student_df['markss_obtained'].mean()
marks_mean
# Out:
# np.float64(58.2)

# %%
student_df['rollno']=student_df['rollno'].fillna(rollno_mode)

# %%
student_df['rollno']
# Out:
# 0    001
# 1    004
# 2    004
# 3    005
# 4    NaN
# Name: rollno, dtype: object
