# %%
import seaborn as sns

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris =pd.read_csv(r"C:\Users\Piyush Deo\Desktop\ml_env\IRIS (1) (2).csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.histplot(data=iris)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data=iris,x='petal_length')
plt.title("distribution of petal_lenght")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# histogram

# %% [markdown]
# distribution plot

# %%
sns.histplot(data=iris,x="petal_width",bins=20,hue="species")
plt.title("distribution of plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data=iris,x="petal_length",bins=50,hue="species")
plt.title("distribution of plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# bargraph

# %%
sns.barplot(data=iris,x="species",y="sepal_length",color='orange',palette='Set2')
plt.title("bargraph of distribution of sepal_length based on species")
# Out:
# C:\Users\Piyush Deo\AppData\Local\Temp\ipykernel_7756\623056438.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=iris,x="species",y="sepal_length",color='orange',palette='Set2')
# Text(0.5, 1.0, 'bargraph of distribution of sepal_length based on species')

# %%
sns.barplot(data=iris,x="species",y="sepal_width",color='orange',palette='Set2')
plt.title("bargraph of distribution of sepal_length based on species")
# Out:
# C:\Users\Piyush Deo\AppData\Local\Temp\ipykernel_7756\4012926008.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=iris,x="species",y="sepal_width",color='orange',palette='Set2')
# Text(0.5, 1.0, 'bargraph of distribution of sepal_length based on species')

# %% [markdown]
# scatter plot

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
sns.scatterplot(data=iris,x='sepal_length',y='petal_length')
plt.show()

# %%
sns.scatterplot(data=iris,x='sepal_length',y='petal_length',hue='species')
plt.show()

# %%
sns.scatterplot(data=iris,x='sepal_width',y='petal_width',hue='species')
plt.show()

# %%
sns.scatterplot(data=iris,x='sepal_length',y='petal_width',hue='species')
plt.show()

# %% [markdown]
# boxplot

# %%
sns.boxplot(data = iris, x ='species', y ='sepal_length')
plt.title("boxplot showing  the distribution of sepal_length")
plt.show()

# %% [markdown]
# heatmap

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
corr_df=iris.drop(columns=['species'])

# %%
corr_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
correlation=corr_df.corr()
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(data=correlation,annot=True)
plt.show()

# %%
sns.heatmap(data=correlation)
plt.show()
